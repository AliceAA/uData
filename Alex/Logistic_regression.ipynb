# %%
import numpy as np
from pylab import *
from sklearn import linear_model

# %%
mean1 = [2, 0]
cov1 = [[1, 1], [1, 10]]

mean2 = [0, 0]
cov2 = [[1.3, 0], [0, 1.6]]

# %%
# Данные 
data1 = np.random.multivariate_normal(mean1, cov1, 10)
print(data1)
data2 = np.random.multivariate_normal(mean2, cov2, 10)
# Out:
# [[ 2.57108485 -0.33790693]
#  [ 2.7023195  -0.27031568]
#  [ 2.06061743 -3.02015872]
#  [ 3.42451374  0.55030521]
#  [ 3.01713075  5.49859438]
#  [ 1.68512632 -0.35802769]
#  [ 2.45540048 -1.45417986]
#  [ 0.98206558  2.4637861 ]
#  [ 2.81667144 -1.04507681]
#  [ 1.28955106  1.45908717]]

# %%
# Формируем обучающую выборку
X = np.vstack([data1, data2])
# Групповая переменная
Y = [0]*len(data1) + [1]*len(data2)


# Настраиваем модель логистической регрессии
logreg = linear_model.LogisticRegression(C=1e5)
logreg.fit(X, Y)
# Out:
# LogisticRegression(C=100000.0, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-df739d991962> in <module>()
# ----> 1 lr = LogisticRegression()
#       2 lr.fit(X, y)
#       3 preds = lr.predict(X)
#
# NameError: name 'LogisticRegression' is not defined

# %%
# Отрисовка результатов классификации и оценок вероятностей

title(u'Результаты классификации')
plot(data1[:, 0], data1[:, 1], 'oy')
plot(data2[:, 0], data2[:, 1], 'sc')
pcolormesh(xx, yy, Z, cmap='RdYlBu')
gca().set_xlim([x_min, x_max])
gca().set_ylim([y_min, y_max])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3af3f1d02a21> in <module>()
#       1 # Отрисовка результатов классификации и оценок вероятностей
#       2
# ----> 3 title(u'Результаты классификации')
#       4 plot(data1[:, 0], data1[:, 1], 'oy')
#       5 plot(data2[:, 0], data2[:, 1], 'sc')
#
# NameError: name 'title' is not defined

# %%
figure()
title(u'Лог-Вероятности класса 1')
pcolormesh(xx, yy, p1, cmap='cool')
colorbar()
gca().set_xlim([x_min, x_max])
gca().set_ylim([y_min, y_max])
# Out:
# (-3.5201587173762863, 5.998594384543757)

# %%
figure()
title(u'Лог-Вероятности класса 2')
pcolormesh(xx, yy, p2, cmap='cool')
colorbar()
gca().set_xlim([x_min, x_max])
gca().set_ylim([y_min, y_max])


show()
